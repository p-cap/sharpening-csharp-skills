// %% [markdown]
// ### C# Declaration

// %% [markdown]
// - declaration with new keyword

// %%
List<Task> tasks = new List<Task>();

// %% [markdown]
// - declaration without the new keyword

// %%
List<Task> task2 = [];

// %% [markdown]
// - class instantiation

// %%
// this is a top-level statment 
// this needs to be instantiated above the class
Pcap pcap = new Pcap();
public class Pcap
{
    public int value;
}
// Out:
// (6,16): warning CS0649: Field 'Pcap.value' is never assigned to, and will always have its default value 0

// %% [markdown]
// - struct declaration

// %%
MyStruct s = new MyStruct();
public struct MyStruct
{
    public int Value;
}
// Out:
// (4,16): warning CS0649: Field 'MyStruct.Value' is never assigned to, and will always have its default value 0

// %% [markdown]
// - array declaration

// %%
int[] numbers = new int[5];

// %% [markdown]
// - delegate????

// %%
MyDelegate del = new MyDelegate(MyMethod);

public delegate void MyDelegate();
// Out:
// (1,33): error CS0103: The name 'MyMethod' does not exist in the current context
// Error: compilation error
