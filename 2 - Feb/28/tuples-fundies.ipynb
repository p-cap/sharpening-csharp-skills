// %% [markdown]
// ### Tuples

// %% [markdown]
// - key-value elements in a tuple

// %%
var pt = (X: 1, Y: 2);
var slope = (double)pt.X / (double)pt.Y;
Console.WriteLine(slope);
// Out:
// 0.5

// %%
pt.X = pt.X + 5;
Console.WriteLine($"The point is now at {pt}.");
// Out:
// The point is now at (6, 2).
