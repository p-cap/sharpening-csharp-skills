// %% [markdown]
// - revisit this problem
// - come up with a way standard way to think through this problem

// %%
using System.Linq;

public class Solution {
    public double FindMedianSortedArrays(int[] nums1, int[] nums2) {
        // return the median of the two arrays
        // median is in decimal
        // odd number of elements is a single element
        // even elements is the averge

        // Approach:
        // binary search
        // combine the two arrays
        // get the mid
        // return the mid

        int left = 0;
        // learining LINQ
        int[] combined = nums1.Concat(nums2).ToArray();

        // when combined, array is NOT sorted
        // make sure to sort the array
        combined.Sort();
        int right = combined.Length;
        string median = "";
        double result = 0;
        int medianIndex = (combined.Length - 1) / 2;
        Console.WriteLine($"medianIndex: {medianIndex}");
        if (combined.Length % 2 == 0) {
            Console.WriteLine($"combined[medianIndex]: {combined[medianIndex]}");
            Console.WriteLine($"combined[medianIndex + 1]: {combined[medianIndex + 1]}");
            // missed the order of operation
            // 2.0 was key to this operation
            result = (combined[medianIndex] + combined[medianIndex + 1]) / 2.0;
            Console.WriteLine($"result: {result}");
        } else {
            Console.WriteLine("This is an ODD length");
            result = combined[medianIndex];
        }   

        Console.WriteLine($"combined[test]: {combined[medianIndex]}");


        // need to learn about casting 
        

        // while(left <= right) {
        //     int mid = left + (right - left) / 2;

        //     if 
        // }

        return result;

    }
}
